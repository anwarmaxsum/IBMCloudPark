# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# Simple Python Code for Heart Failure Analysis

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

myarr = df_data_1.values
plt.figure
plt.bar(myarr[:,0],myarr[:,2])
plt.show()

plt.figure
plt.scatter(myarr[:,0],myarr[:,6])
plt.show()

y = myarr[:,12]
x1 = myarr[y==0,:]
x2 = myarr[y==1,:]

plt.figure
plt.scatter(x1[:,0], x1[:,4], color='blue')
plt.scatter(x2[:,0], x2[:,4], color='red')
plt.show()

# %%
df2 = df_data_1[['age','DEATH_EVENT']]

# %%
df2.to_csv('newdata.csv')

# %%
# !ls
# Out:
# newdata.csv

# %%
# !pwd
# Out:
# /home/dsxuser/work

# %%
project.save_data("file_name.csv", df2.to_csv(index=False))
# Out:
# {'file_name': 'file_name.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'introtoibmtools-donotdelete-pr-rntfgy3mrovtu3',
#  'asset_id': '05d3dae2-3540-4fd9-a391-babd4d34aa1a'}
